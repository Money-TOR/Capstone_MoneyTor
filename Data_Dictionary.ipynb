# %% [markdown]
# # CAPSTONE PROJECT : MONEY-TOR [DATA SCIENCE]
# - CDCC325D6Y0761 - Ignatius William Alvin
# - CDCC325D6Y2656 - Jason Nathannael

# %% [markdown]
# ## Import Library & Load Dataset

# %%
# Data Dictionary - Main Dataset UMKM

# Import library
import pandas as pd

# Load Dataset
main_data = pd.read_csv('main_data.csv')

# %% [markdown]
# ## Mengecek Struktur Dataset (Shape, Info, Head)

# %%
# Cek ukuran dataset
main_data.shape
# Out:
# (30000, 29)

# %%
# Cek 5 baris teratas
main_data.head()
# Out:
#   id_transaksi id_seller id_produk     tanggal jam_transaksi jenis_transaksi  \
# 0      T000001      U006      P040  2025-08-23         10:47       Pemasukan
# 1      T000001      U006      P036  2025-08-23         10:47       Pemasukan
# 2      T000002      U005      P032  2026-10-10         08:35       Pemasukan
# 3      T000002      U005      P034  2026-10-10         08:35       Pemasukan
# 4      T000003      U002      P007  2026-07-14         12:17       Pemasukan
#
#   kategori  qty  harga_satuan  total_harga  ... harga_jual harga_modal  \
# 0  Fashion    2         50000       100000  ...      50000       25000
# 1  Fashion    1        150000       150000  ...     150000       90000
# 2  Laundry    5         15000        75000  ...      15000        8000
# 3  Laundry    1          7000         7000  ...       7000        3000
# 4  Sembako    7         70000       416500  ...      70000       60000
#
#    stok_awal minimum_stok  status_produk  tanggal_input_produk     nama_usaha  \
# 0        412           82   stok_menipis            2025-05-07     Thrift Hub
# 1        534          107          aktif            2025-05-12     Thrift Hub
# 2       4148          830          aktif            2025-02-02      CleanWash
# 3       4294          859          aktif            2025-02-11      CleanWash
# 4       2907          581          aktif            2024-03-10  Warung Madura
#
#   jenis_usaha lokasi_usaha  tanggal_bergabung
# 0     Fashion      Bandung         2025-05-01
# 1     Fashion      Bandung         2025-05-01
# 2     Laundry      Bandung         2025-02-01
# 3     Laundry      Bandung         2025-02-01
# 4      Retail       Cimahi         2024-03-01
#
# [5 rows x 29 columns]

# %%
# Cek info dataset
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_transaksi          30000 non-null  object
#  1   id_seller             30000 non-null  object
#  2   id_produk             30000 non-null  object
#  3   tanggal               30000 non-null  object
#  4   jam_transaksi         30000 non-null  object
#  5   jenis_transaksi       30000 non-null  object
#  6   kategori              30000 non-null  object
#  7   qty                   30000 non-null  int64
#  8   harga_satuan          30000 non-null  int64
#  9   total_harga           30000 non-null  int64
#  10  metode_pembayaran     30000 non-null  object
#  11  event                 30000 non-null  object
#  12  diskon                30000 non-null  int64
#  13  status_transaksi      30000 non-null  object
#  14  tahun                 30000 non-null  int64
#  15  bulan                 30000 non-null  int64
#  16  id_supplier           30000 non-null  object
#  17  nama_produk           30000 non-null  object
#  18  kategori_produk       30000 non-null  object
#  19  harga_jual            30000 non-null  int64
#  20  harga_modal           30000 non-null  int64
#  21  stok_awal             30000 non-null  int64
#  22  minimum_stok          30000 non-null  int64
#  23  status_produk         30000 non-null  object
#  24  tanggal_input_produk  30000 non-null  object
#  25  nama_usaha            30000 non-null  object
#  26  jenis_usaha           30000 non-null  object
#  27  lokasi_usaha          30000 non-null  object
#  28  tanggal_bergabung     30000 non-null  object
# dtypes: int64(10), object(19)
# memory usage: 6.6+ MB

# %% [markdown]
# ## Data Dictionary
#
# | Kolom | Tipe Data | Deskripsi |
# |---|---|---|
# | id_transaksi | object | ID unik transaksi |
# | id_seller | object | ID seller UMKM |
# | id_produk | object | ID produk |
# | tanggal | datetime | Tanggal transaksi |
# | jam_transaksi | object | Waktu transaksi |
# | jenis_transaksi | object | Jenis transaksi pemasukan atau pengeluaran |
# | kategori | object | Kategori transaksi |
# | qty | int | Jumlah produk yang dibeli |
# | harga_satuan | int | Harga per item |
# | total_harga | int | Total nilai transaksi |
# | metode_pembayaran | object | Metode pembayaran transaksi |
# | event | object | Event promosi transaksi |
# | diskon | int | Besaran diskon transaksi |
# | status_transaksi | object | Status transaksi berhasil atau dibatalkan |
# | tahun | int | Tahun transaksi |
# | bulan | int | Bulan transaksi |
# | id_supplier | object | ID supplier |
# | nama_produk | object | Nama produk |
# | kategori_produk | object | Kategori produk |
# | harga_jual | int | Harga jual produk |
# | harga_modal | int | Harga modal produk |
# | stok_awal | int | Jumlah stok awal produk |
# | minimum_stok | int | Minimum batas stok |
# | status_produk | object | Status produk |
# | tanggal_input_produk | datetime | Tanggal input produk |
# | nama_usaha | object | Nama usaha seller |
# | jenis_usaha | object | Jenis usaha seller |
# | lokasi_usaha | object | Lokasi usaha seller |
# | tanggal_bergabung | datetime | Tanggal seller bergabung |

# %% [markdown]
# ## KESIAPAN DATASET
#
# Dataset `main_data` merupakan hasil akhir proses data wrangling yang telah melalui tahapan assessing data, cleaning data, transformasi tipe data, dan merge dataset. Dataset ini telah bersih dari missing value dan data duplikat sehingga siap digunakan untuk proses analisis lanjutan maupun dashboard interaktif menggunakan Streamlit.
